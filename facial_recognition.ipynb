# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaif10/Computer-Vision-with-OpenCV-and-Keras/blob/master/facial_recognition.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Face and eyes detection with haarcascade classifier

# %%
#import
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# Define Classifiers

# %%
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('haarcascade_eye.xml')

# %%
#input image
img = cv2.imread('face.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
faces = face_cascade.detectMultiScale(gray, 1.3, 5)
#loop through the no of faces
for (x,y,w,h) in faces:
    img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)

# %%
#display image
plt.imshow(img)
cv2.waitKey(0)
cv2.destroyAllWindows()
